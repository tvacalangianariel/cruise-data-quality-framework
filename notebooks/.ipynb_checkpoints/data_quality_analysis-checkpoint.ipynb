# %%
#setup
import pandas as pd
import matplotlib.pyplot as plt

bookings = pd.read_csv("../data/bookings.csv")
passengers = pd.read_csv("../data/passengers.csv")
payments = pd.read_csv("../data/payments.csv")

print("Datasets loaded.")
# Out:
# Datasets loaded.

# %%
#basic overview
print(bookings.head())
print(passengers.head())
print(payments.head())

print("Bookings shape:", bookings.shape)
print("Passengers shape:", passengers.shape)
print("Payments shape:", payments.shape)
# Out:
#    booking_id              ship                booking_date  \
# 0  1000000000       Sea Voyager  2026-01-14 23:59:09.930115
# 1  1000000001    Atlantic Dream  2025-07-14 23:59:09.930227
# 2  1000000002       Sea Voyager  2025-07-17 23:59:09.930268
# 3  1000000003  Oceanic Explorer  2025-09-03 23:59:09.930300
# 4  1000000004       Sea Voyager  2025-08-23 23:59:09.930323
#
#                  sailing_date  occupants  total_fare
# 0  2026-02-22 23:59:09.930115          2      130.42
# 1  2026-01-08 23:59:09.930227          2     4152.00
# 2  2025-11-01 23:59:09.930268          2     2943.89
# 3  2026-01-12 23:59:09.930300          1       48.20
# 4  2026-02-14 23:59:09.930323          1     3061.82
#    passenger_id  booking_id     passenger_name gender  passenger_email
# 0   10000000000  1000000000  Guest_10000000000      M  user0@email.com
# 1   10000000001  1000000000  Guest_10000000001      M  user1@email.com
# 2   10000000010  1000000001  Guest_10000000010      M  user0@email.com
# 3   10000000011  1000000001  Guest_10000000011      F  user1@email.com
# 4   10000000020  1000000002  Guest_10000000020      F  user0@email.com
#    transaction_id  booking_id  passenger_id  payment_amount payment_status
# 0   1000000000000  1000000000   10000000000         2463.18        Pending
# 1   1000000000100  1000000000   10000000001          292.26        Pending
# 2   1000000001000  1000000001   10000000010          218.93           Paid
# 3   1000000001100  1000000001   10000000011         2426.98           Paid
# 4   1000000002000  1000000002   10000000020         1069.87        Pending
# Bookings shape: (10000, 6)
# Passengers shape: (24898, 5)
# Payments shape: (24898, 5)

# %%
#missing
missing = bookings.isnull().sum()

missing.plot(kind="bar", title="Missing Values per Column")
plt.show()

# %%
#duplicates analysis
duplicates = bookings.duplicated().sum()
print("Duplicate bookings:", duplicates)
# Out:
# Duplicate bookings: 0

# %%
#business rule validation
#  -invalid sailing dates
invalid_dates = (bookings["sailing_date"] < bookings["booking_date"]).sum()
print("Invalid sailing dates:", invalid_dates)
# Out:
# Invalid sailing dates: 472

# %%
#  -negative fare prices
negative_prices = (bookings["total_fare"] < 0).sum()
print("Negative fares:", negative_prices)
# Out:
# Negative fares: 436

# %%
#cross-table validation
#  -orphan passengers 
invalid_passengers = passengers[
    ~passengers["booking_id"].isin(bookings["booking_id"])
]

print("Orphan passengers:", len(invalid_passengers))
# Out:
# Orphan passengers: 0

# %%
#  -payment mismatch
payment_sum = payments.groupby("booking_id")["payment_amount"].sum()

merged = bookings.set_index("booking_id").join(payment_sum)

overpaid = (merged["payment_amount"] > merged["total_fare"]).sum()

print("Overpaid bookings:", overpaid)
# Out:
# Overpaid bookings: 5900

# %%
#data quality score
total_issues = (
    duplicates +
    invalid_dates +
    negative_prices +
    len(invalid_passengers) +
    overpaid
)

total_records = len(bookings)

score = 100 - ((total_issues / total_records) * 100)

print("Data Quality Score:", round(score, 2), "%")
# Out:
# Data Quality Score: 31.92 %

# %%
#visualization
#  -booking distribution
bookings["cabin_type"].value_counts().plot(kind="bar", title="Cabin Type Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cabin_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 #visualization
#       2 #  -booking distribution
# ----> 3 bookings["cabin_type"].value_counts().plot(kind="bar", title="Cabin Type Distribution")
#       4 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'cabin_type'

# %%
#payment status
payments["payment_status"].value_counts().plot(kind="bar", title="Payment Status")
plt.show()

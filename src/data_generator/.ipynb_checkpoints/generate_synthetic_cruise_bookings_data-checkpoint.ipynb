# %%
import pandas as pd
import random
from datetime import datetime, timedelta

bookings = []
passengers = []
payments = []

# create 10,000 bookings
for b in range(10000):
    booking_id = 1000000000 + b
    ship = random.choice(["Oceanic Explorer", "Sea Voyager", "Atlantic Dream"])
    booking_date = datetime.now() - timedelta(days=random.randint(1, 365))
    sailing_date = booking_date + timedelta(days=random.randint(-10, 200))  # invalid cases

    occupants = random.randint(1, 4)
    total_fare = round(random.uniform(-500, 10000), 2)

    bookings.append({
        "booking_id": booking_id,
        "ship": ship,
        "booking_date": booking_date,
        "sailing_date": sailing_date,
        "occupants": occupants,
        "total_fare": total_fare
        })

    for p in range(occupants):
        passenger_id = booking_id * 10 + p

        passengers.append({
            "passenger_id": passenger_id,
            "booking_id": booking_id,
            "passenger_name": f"Guest_{passenger_id}",
            "gender": random.choice(["M", "F"]),
            "passenger_email": None if random.random() < 0.05 else f"user{p}@email.com"
        })
        
        payments.append({
            "transaction_id": passenger_id * 100,
            "booking_id": booking_id,
            "passenger_id": passenger_id,
            "payment_amount": round(random.uniform(-200, 5000), 2),
            "payment_status": random.choice(["Paid", "Pending", "Failed"])
        })

# %%
print(bookings)
# Out:
# [{'booking_id': 1000000000, 'ship': 'Oceanic Explorer', 'booking_date': datetime.datetime(2025, 10, 10, 21, 35, 3, 32301), 'sailing_date': datetime.datetime(2025, 10, 27, 21, 35, 3, 32301), 'occupants': 2, 'total_fare': 8427.19}, {'booking_id': 1000000001, 'ship': 'Sea Voyager', 'booking_date': datetime.datetime(2025, 9, 17, 21, 35, 3, 32445), 'sailing_date': datetime.datetime(2025, 10, 26, 21, 35, 3, 32445), 'occupants': 2, 'total_fare': 6443.73}, {'booking_id': 1000000002, 'ship': 'Sea Voyager', 'booking_date': datetime.datetime(2025, 8, 13, 21, 35, 3, 32502), 'sailing_date': datetime.datetime(2025, 10, 29, 21, 35, 3, 32502), 'occupants': 3, 'total_fare': 9811.26}, {'booking_id': 1000000003, 'ship': 'Sea Voyager', 'booking_date': datetime.datetime(2026, 3, 11, 21, 35, 3, 32569), 'sailing_date': datetime.datetime(2026, 5, 19, 21, 35, 3, 32569), 'occupants': 1, 'total_fare': 728.3}, {'booking_id': 1000000004, 'ship': 'Sea Voyager', 'booking_date': datetime.datetime(2025, 6, 2, 21, 35, 3, 32654), 'sailing_date': datetime.datetime(2025, 10, 26, 21, 35, 3, 32654), 'occupants': 2, 'total_fare': 9602.48}, {'booking_id': 1000000005, 'ship': 'Oceanic Explorer', 'booking_date': datetime.datetime(2025, 10, 12, 21, 35, 3, 32697), 'sailing_date': datetime.datetime(2026, 2, 11, 21, 35, 3, 32697), 'occupants': 3, 'total_fare': 4515.63}, {'booking_id': 1000000006, 'ship': 'Oceanic Explorer', 'booking_date': datetime.datetime(2025, 3, 26, 21, 35, 3, 32820), 'sailing_date': datetime.datetime(2025, 5, 18, 21, 35, 3, 32820), 'occupants': 2, 'total_fare': 3969.7}, {'booking_id': 1000000007, 'ship': 'Atlantic Dream', 'booking_date': datetime.datetime(2025, 8, 10, 21, 35, 3, 32859), 'sailing_date': datetime.datetime(2025, 12, 19, 21, 35, 3, 32859), 'occupants': 2, 'total_fare': 6513.3}, {'booking_id': 1000000008, 'ship': 'Oceanic Explorer', 'booking_date': datetime.datetime(2026, 2, 28, 21, 35, 3, 32896), 'sailing_date': datetime.datetime(2026, 6, 28, 21, 35, 3, 32896), 'occupants': 4, 'total_fare': 8911.31}, {'booking_id': 1000000009, 'ship': 'Oceanic Explorer', 'booking_date': datetime.datetime(2025, 10, 10, 21, 35, 3, 32953), 'sailing_date': datetime.datetime(2025, 11, 27, 21, 35, 3, 32953), 'occupants': 2, 'total_fare': 3931.74}, {'booking_id': 1000000010, 'ship': 'Atlantic Dream', 'booking_date': datetime.datetime(2025, 8, 24, 21, 35, 3, 32986), 'sailing_date': datetime.datetime(2025, 12, 16, 21, 35, 3, 32986), 'occupants': 1, 'total_fare': 192.46}, {'booking_id': 1000000011, 'ship': 'Oceanic Explorer', 'booking_date': datetime.datetime(2025, 11, 18, 21, 35, 3, 33008), 'sailing_date': datetime.datetime(2026, 2, 25, 21, 35, 3, 33008), 'occupants': 2, 'total_fare': 5972.52}, {'booking_id': 1000000012, 'ship': 'Oceanic Explorer', 'booking_date': datetime.datetime(2025, 12, 25, 21, 35, 3, 33042), 'sailing_date': datetime.datetime(2026, 3, 23, 21, 35, 3, 33042), 'occupants': 2, 'total_fare': 7740.97}, {'booking_id': 1000000013, 'ship': 'Sea Voyager', 'booking_date': datetime.datetime(2025, 9, 9, 21, 35, 3, 33083), 'sailing_date': datetime.datetime(2025, 10, 8, 21, 35, 3, 33083), 'occupants': 1, 'total_fare': 9367.25}, {'booking_id': 1000000014, 'ship': 'Atlantic Dream', 'booking_date': datetime.datetime(2026, 1, 9, 21, 35, 3, 33144), 'sailing_date': datetime.datetime(2026, 5, 17, 21, 35, 3, 33144), 'occupants': 3, 'total_fare': 1794.18}, {'booking_id': 1000000015, 'ship': 'Sea Voyager', 'booking_date': datetime.datetime(2025, 11, 16, 21, 35, 3, 33187), 'sailing_date': datetime.datetime(2026, 4, 11, 21, 35, 3, 33187), 'occupants': 1, 'total_fare': 4182.23}, {'booking_id': 1000000016, 'ship': 'Oceanic Explorer', 'booking_date': datetime.datetime(2025, 10, 12, 21, 35, 3, 33214), 'sailing_date': datetime.datetime(2026, 4, 27, 21, 35, 3, 33214), 'occupants': 2, 'total_fare': -219.42}, {'booking_id': 1000000017, 'ship': 'Atlantic Dream', 'booking_date': datetime.datetime(2025, 4, 10, 21, 35, 3, 33258), 'sailing_date': datetime.datetime(2025, 10, 9, 21,  ...

# %%
len(bookings)
# Out:
# 10000

# %%
print(passengers[:10])
# Out:
# [{'passenger_id': 10000000000, 'booking_id': 1000000000, 'passenger_name': 'Guest_10000000000', 'gender': 'M', 'passenger_email': 'user0@email.com'}, {'passenger_id': 10000000001, 'booking_id': 1000000000, 'passenger_name': 'Guest_10000000001', 'gender': 'M', 'passenger_email': 'user1@email.com'}, {'passenger_id': 10000000010, 'booking_id': 1000000001, 'passenger_name': 'Guest_10000000010', 'gender': 'M', 'passenger_email': 'user0@email.com'}, {'passenger_id': 10000000011, 'booking_id': 1000000001, 'passenger_name': 'Guest_10000000011', 'gender': 'M', 'passenger_email': 'user1@email.com'}, {'passenger_id': 10000000020, 'booking_id': 1000000002, 'passenger_name': 'Guest_10000000020', 'gender': 'F', 'passenger_email': 'user0@email.com'}, {'passenger_id': 10000000021, 'booking_id': 1000000002, 'passenger_name': 'Guest_10000000021', 'gender': 'M', 'passenger_email': 'user1@email.com'}, {'passenger_id': 10000000022, 'booking_id': 1000000002, 'passenger_name': 'Guest_10000000022', 'gender': 'M', 'passenger_email': 'user2@email.com'}, {'passenger_id': 10000000030, 'booking_id': 1000000003, 'passenger_name': 'Guest_10000000030', 'gender': 'F', 'passenger_email': 'user0@email.com'}, {'passenger_id': 10000000040, 'booking_id': 1000000004, 'passenger_name': 'Guest_10000000040', 'gender': 'M', 'passenger_email': 'user0@email.com'}, {'passenger_id': 10000000041, 'booking_id': 1000000004, 'passenger_name': 'Guest_10000000041', 'gender': 'F', 'passenger_email': 'user1@email.com'}]

# %%
len(passengers)
# Out:
# 24947

# %%
print(payments[:10]
# Out:
# [{'transaction_id': 1000000000000, 'booking_id': 1000000000, 'passenger_id': 10000000000, 'payment_amount': 3996.37, 'payment_status': 'Pending'}, {'transaction_id': 1000000000100, 'booking_id': 1000000000, 'passenger_id': 10000000001, 'payment_amount': 1749.97, 'payment_status': 'Pending'}, {'transaction_id': 1000000001000, 'booking_id': 1000000001, 'passenger_id': 10000000010, 'payment_amount': 4234.67, 'payment_status': 'Paid'}, {'transaction_id': 1000000001100, 'booking_id': 1000000001, 'passenger_id': 10000000011, 'payment_amount': 449.58, 'payment_status': 'Paid'}, {'transaction_id': 1000000002000, 'booking_id': 1000000002, 'passenger_id': 10000000020, 'payment_amount': 329.44, 'payment_status': 'Pending'}, {'transaction_id': 1000000002100, 'booking_id': 1000000002, 'passenger_id': 10000000021, 'payment_amount': 4230.1, 'payment_status': 'Pending'}, {'transaction_id': 1000000002200, 'booking_id': 1000000002, 'passenger_id': 10000000022, 'payment_amount': 4517.02, 'payment_status': 'Failed'}, {'transaction_id': 1000000003000, 'booking_id': 1000000003, 'passenger_id': 10000000030, 'payment_amount': 2579.29, 'payment_status': 'Paid'}, {'transaction_id': 1000000004000, 'booking_id': 1000000004, 'passenger_id': 10000000040, 'payment_amount': 3972.92, 'payment_status': 'Paid'}, {'transaction_id': 1000000004100, 'booking_id': 1000000004, 'passenger_id': 10000000041, 'payment_amount': 4382.38, 'payment_status': 'Failed'}]

# %%
len(payments)
# Out:
# 24947

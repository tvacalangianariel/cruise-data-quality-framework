# %% [markdown]
# # Cruise Reservation Data Quality Analysis
#
# This notebook analyzes the quality of a synthetic cruise reservation dataset.
#
# ## Objectives
# - Identify data quality issues
# - Validate business rules
# - Analyze booking and payment patterns
# - Compute overall data quality score

# %% [markdown]
# ### Section 1: Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt

bookings = pd.read_csv("../data/bookings.csv")
passengers = pd.read_csv("../data/passengers.csv")
payments = pd.read_csv("../data/payments.csv")

print("Datasets loaded.")
# Out:
# Datasets loaded.

# %% [markdown]
# ### Section 2: Basic Overview

# %%
print(bookings.head())
print(passengers.head())
print(payments.head())

print("Bookings shape:", bookings.shape)
print("Passengers shape:", passengers.shape)
print("Payments shape:", payments.shape)
# Out:
#    booking_id              ship                booking_date  \
# 0  1000000000    Atlantic Dream  2025-10-24 21:56:17.542812
# 1  1000000001    Atlantic Dream  2025-05-08 21:56:17.542862
# 2  1000000002       Sea Voyager  2026-01-26 21:56:17.542878
# 3  1000000003  Oceanic Explorer  2025-09-26 21:56:17.542886
# 4  1000000004       Sea Voyager  2025-06-17 21:56:17.542904
#
#                  sailing_date  occupants cabin_type  total_fare
# 0  2026-04-27 21:56:17.542812          2    Balcony     5446.14
# 1  2025-08-19 21:56:17.542862          2   Interior     5544.17
# 2  2026-05-07 21:56:17.542878          1      Suite     6928.88
# 3  2025-11-18 21:56:17.542886          2      Suite     6735.41
# 4  2025-07-05 21:56:17.542904          2      Suite     3810.47
#    passenger_id  booking_id     passenger_name gender  passenger_email
# 0   10000000000  1000000000  Guest_10000000000      F  user0@email.com
# 1   10000000001  1000000000  Guest_10000000001      M  user1@email.com
# 2   10000000010  1000000001  Guest_10000000010      F  user0@email.com
# 3   10000000011  1000000001  Guest_10000000011      M              NaN
# 4   10000000020  1000000002  Guest_10000000020      M  user0@email.com
#    transaction_id  booking_id  passenger_id  payment_amount payment_status
# 0   1000000000000  1000000000   10000000000         4909.67        Pending
# 1   1000000000100  1000000000   10000000001         4110.30        Pending
# 2   1000000001000  1000000001   10000000010         3650.09           Paid
# 3   1000000001100  1000000001   10000000011          333.12         Failed
# 4   1000000002000  1000000002   10000000020         3544.23        Pending
# Bookings shape: (10000, 7)
# Passengers shape: (25268, 5)
# Payments shape: (25268, 5)

# %% [markdown]
# ### Section 3: Missing Data Analysis

# %%
missing = bookings.isnull().sum()

missing.plot(kind="bar", title="Missing Values per Column")
plt.show()

# %% [markdown]
# ### Section 4: Duplicate Analysis

# %%
duplicates = bookings.duplicated().sum()
print("Duplicate bookings:", duplicates)
# Out:
# Duplicate bookings: 0

# %% [markdown]
# ### Section 5: Business Rule Validation

# %%
#Invalid sailing dates
invalid_dates = (bookings["sailing_date"] < bookings["booking_date"]).sum()
print("Invalid sailing dates:", invalid_dates)
# Out:
# Invalid sailing dates: 481

# %%
#Negative fare prices
negative_prices = (bookings["total_fare"] < 0).sum()
print("Negative fares:", negative_prices)
# Out:
# Negative fares: 469

# %% [markdown]
# ### Section 6: Cross-Table Validation

# %%
#Orphan passengers 
invalid_passengers = passengers[
    ~passengers["booking_id"].isin(bookings["booking_id"])
]

print("Orphan passengers:", len(invalid_passengers))
# Out:
# Orphan passengers: 0

# %%
#Payment mismatch
payment_sum = payments.groupby("booking_id")["payment_amount"].sum()

merged = bookings.set_index("booking_id").join(payment_sum)

overpaid = (merged["payment_amount"] > merged["total_fare"]).sum()

print("Overpaid bookings:", overpaid)
# Out:
# Overpaid bookings: 5888

# %% [markdown]
# ### Section 7: Data Quality Score

# %%
total_issues = (
    duplicates +
    invalid_dates +
    negative_prices +
    len(invalid_passengers) +
    overpaid
)

total_records = len(bookings)

score = 100 - ((total_issues / total_records) * 100)

print("Data Quality Score:", round(score, 2), "%")
# Out:
# Data Quality Score: 31.62 %

# %% [markdown]
# ### Section 8: Visualization

# %%
#Booking distribution
bookings["cabin_type"].value_counts().plot(kind="bar", title="Cabin Type Distribution")
plt.show()

# %%
#Payment Status
payments["payment_status"].value_counts().plot(kind="bar", title="Payment Status")
plt.show()

# %% [markdown]
# ## Key Findings
#
# - Sample 01: Duplicate bookings detected due to ID collisions
# - Sample 02: Missing emails impact customer communication
# - Sample 03: Invalid sailing dates indicate booking system issues
# - Sample 04: Payment inconsistencies affect revenue reporting
#
# ## Recommendation
#
# Implement automated validation checks before data enters reporting systems.
